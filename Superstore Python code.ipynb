# %%
##Superstore data
import pandas as pd
import numpy as np

# %%
##1
data=pd.read_csv("C:\\Users\\91879\\Downloads\\Superstore.csv",encoding='latin1')

# %%
data.head()
# Out:
#     no       order _id  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  NaN             NaN  08-11-2016  11-11-2016    Second Class    CG-12520
# 1  2.0  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 2  3.0  CA-2016-138688  12-06-2016  16-06-2016    Second Class    DV-13045
# 3  4.0  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
# 4  5.0  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df=pd.DataFrame(data)
df.head()
# Out:
#     no       order _id  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  NaN             NaN  08-11-2016  11-11-2016    Second Class    CG-12520
# 1  2.0  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 2  3.0  CA-2016-138688  12-06-2016  16-06-2016    Second Class    DV-13045
# 3  4.0  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
# 4  5.0  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
##2
data.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
#3
data.columns
# Out:
# Index(['no', 'order _id', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
##4
data.columns.str.replace(' ', '_')
# Out:
# Index(['no', 'order__id', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State',
#        'Postal_Code', 'Region', 'Product_ID', 'Category', 'Sub-Category',
#        'Product_Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
data.rename(columns={"no":"Serial_No"},inplace=True)
data
# Out:
#       Serial_No       order _id  Order Date   Ship Date       Ship Mode  \
# 0           NaN             NaN  08-11-2016  11-11-2016    Second Class
# 1           2.0  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 2           3.0  CA-2016-138688  12-06-2016  16-06-2016    Second Class
# 3           4.0  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 4           5.0  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# ...         ...             ...         ...         ...             ...
# 9989     9990.0  CA-2014-110422  21-01-2014  23-01-2014    Second Class
# 9990     9991.0  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9991     9992.0  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9992     9993.0  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9993     9994.0  CA-2017-119914  04-05-2017  09-05-2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
##5
data.head(40)
# Out:
#     Serial_No       order _id  Order Date   Ship Date       Ship Mode  \
# 0         NaN             NaN  08-11-2016  11-11-2016    Second Class
# 1         2.0  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 2         3.0  CA-2016-138688  12-06-2016  16-06-2016    Second Class
# 3         4.0  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 4         5.0  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 5         6.0  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 6         7.0  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 7         8.0  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 8         9.0  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 9        10.0  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 10       11.0  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 11       12.0  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# ...

# %%
##6
data.tail(15)
# Out:
#       Serial_No       order _id  Order Date   Ship Date       Ship Mode  \
# 9979     9980.0  US-2016-103674  06-12-2016  10-12-2016  Standard Class
# 9980     9981.0  US-2015-151435  06-09-2015  09-09-2015    Second Class
# 9981     9982.0  CA-2017-163566  03-08-2017  06-08-2017     First Class
# 9982     9983.0  US-2016-157728  22-09-2016  28-09-2016  Standard Class
# 9983     9984.0  US-2016-157728  22-09-2016  28-09-2016  Standard Class
# 9984     9985.0  CA-2015-100251  17-05-2015  23-05-2015  Standard Class
# 9985     9986.0  CA-2015-100251  17-05-2015  23-05-2015  Standard Class
# 9986     9987.0  CA-2016-125794  29-09-2016  03-10-2016  Standard Class
# 9987     9988.0  CA-2017-163629  17-11-2017  21-11-2017  Standard Class
# 9988     9989.0  CA-2017-163629  17-11-2017  21-11-2017  Standard Class
# 9989     9990.0  CA-2014-110422  21-01-2014  23-01-2014    Second Class
# 9990     9991.0  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# ...

# %%
df=pd.DataFrame(data)
df.head()
# Out:
#    Serial_No       order _id  Order Date   Ship Date       Ship Mode  \
# 0        NaN             NaN  08-11-2016  11-11-2016    Second Class
# 1        2.0  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 2        3.0  CA-2016-138688  12-06-2016  16-06-2016    Second Class
# 3        4.0  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 4        5.0  US-2015-108966  11-10-2015  18-10-2015  Standard Class
#
#   Customer ID    Customer Name    Segment        Country             City  \
# 0    CG-12520      Claire Gute   Consumer  United States        Henderson
# 1    CG-12520      Claire Gute   Consumer  United States        Henderson
# 2    DV-13045  Darrin Van Huff  Corporate  United States      Los Angeles
# 3    SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4    SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#    ... Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
##7
pd.options.display.min_rows =30

# %%
df
# Out:
#       Serial_No       order _id  Order Date   Ship Date       Ship Mode  \
# 0           NaN             NaN  08-11-2016  11-11-2016    Second Class
# 1           2.0  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 2           3.0  CA-2016-138688  12-06-2016  16-06-2016    Second Class
# 3           4.0  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 4           5.0  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 5           6.0  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 6           7.0  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 7           8.0  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 8           9.0  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 9          10.0  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 10         11.0  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 11         12.0  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# ...

# %%
##8
pd.options.display.min_rows =3

# %%
df
# Out:
#       Serial_No       order _id  Order Date   Ship Date     Ship Mode  \
# 0           NaN             NaN  08-11-2016  11-11-2016  Second Class
# ...         ...             ...         ...         ...           ...
# 9993     9994.0  CA-2017-119914  04-05-2017  09-05-2017  Second Class
#
#      Customer ID Customer Name   Segment        Country         City  ...  \
# 0       CG-12520   Claire Gute  Consumer  United States    Henderson  ...
# ...          ...           ...       ...            ...          ...  ...
# 9993    CC-12220  Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# 0          42420   South  FUR-BO-10001798        Furniture    Bookcases
# ...          ...     ...              ...              ...          ...
# 9993       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name   Sales  Quantity  \
# ...

# %%
#9
cols=["City","State","Region","Profit"]

# %%
df[cols]
# Out:
#              City       State Region   Profit
# 0       Henderson    Kentucky  South  41.9136
# ...           ...         ...    ...      ...
# 9993  Westminster  California   West  72.9480
#
# [9994 rows x 4 columns]

# %%
#10
df.iloc[1000:1501,4:8]
# Out:
#            Ship Mode Customer ID  Customer Name      Segment
# 1000  Standard Class    FM-14290   Frank Merwin  Home Office
# ...              ...         ...            ...          ...
# 1500  Standard Class    NG-18430  Nathan Gelder     Consumer
#
# [501 rows x 4 columns]

# %%
#11
df.index=range(1900,1900+len(df))

# %%
df
# Out:
#        Serial_No       order _id  Order Date   Ship Date     Ship Mode  \
# 1900         NaN             NaN  08-11-2016  11-11-2016  Second Class
# ...          ...             ...         ...         ...           ...
# 11893     9994.0  CA-2017-119914  04-05-2017  09-05-2017  Second Class
#
#       Customer ID Customer Name   Segment        Country         City  ...  \
# 1900     CG-12520   Claire Gute  Consumer  United States    Henderson  ...
# ...           ...           ...       ...            ...          ...  ...
# 11893    CC-12220  Chris Cortes  Consumer  United States  Westminster  ...
#
#       Postal Code  Region       Product ID         Category Sub-Category  \
# 1900        42420   South  FUR-BO-10001798        Furniture    Bookcases
# ...           ...     ...              ...              ...          ...
# 11893       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             Product Name   Sales  Quantity  \
# ...

# %%
#12
df.loc[[1920,1940,1945,1980],["Profit", "State", "Category", "Sub-Category", "Region"]]
# Out:
#        Profit       State         Category Sub-Category   Region
# 1920   7.3840  California  Office Supplies      Binders     West
# 1940  41.7564       Texas       Technology       Phones  Central
# 1945   8.2062   Minnesota  Office Supplies      Binders  Central
# 1980   8.0352     Alabama  Office Supplies      Binders    South

# %%
##13
df.dtypes
# Out:
# Serial_No        float64
# order _id         object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
##14
df[(df['Order Date']>='01-06-2014') & (df['Order Date']<='30-06-2014')].head()
# Out:
#       Serial_No       order _id  Order Date   Ship Date       Ship Mode  \
# 1900        NaN             NaN  08-11-2016  11-11-2016    Second Class
# 1901        2.0  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 1902        3.0  CA-2016-138688  12-06-2016  16-06-2016    Second Class
# 1903        4.0  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 1904        5.0  US-2015-108966  11-10-2015  18-10-2015  Standard Class
#
#      Customer ID    Customer Name    Segment        Country             City  \
# 1900    CG-12520      Claire Gute   Consumer  United States        Henderson
# 1901    CG-12520      Claire Gute   Consumer  United States        Henderson
# 1902    DV-13045  Darrin Van Huff  Corporate  United States      Los Angeles
# 1903    SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 1904    SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
# ...

# %%
df[(df['Order Date']>='01-06-2014') & (df['Order Date']<='30-06-2014')].shape
# Out:
# (9566, 21)

# %%
##15
data['Order Date'] = pd.to_datetime(data['Order Date'], errors='coerce')

data['Month'] = data['Order Date'].dt.month
data['Year'] = data['Order Date'].dt.year

avg_profit = data.groupby('Month')['Profit'].mean()
avg_profit
# Out:
# Month
# 1.0     50.465208
# 2.0     51.295754
# 3.0     19.426091
# 4.0     22.317002
# 5.0     20.487142
# 6.0     26.279641
# 7.0     12.661376
# 8.0     33.956539
# 9.0     28.828962
# 10.0    17.717636
# 11.0    19.140760
# 12.0    15.761431
# Name: Profit, dtype: float64

# %%
#16
df[df['State']=="California"]
# Out:
#        Serial_No       order _id  Order Date   Ship Date     Ship Mode  \
# 1902         3.0  CA-2016-138688  12-06-2016  16-06-2016  Second Class
# ...          ...             ...         ...         ...           ...
# 11893     9994.0  CA-2017-119914  04-05-2017  09-05-2017  Second Class
#
#       Customer ID    Customer Name    Segment        Country         City  \
# 1902     DV-13045  Darrin Van Huff  Corporate  United States  Los Angeles
# ...           ...              ...        ...            ...          ...
# 11893    CC-12220     Chris Cortes   Consumer  United States  Westminster
#
#        ... Postal Code  Region       Product ID         Category Sub-Category  \
# 1902   ...       90036    West  OFF-LA-10000240  Office Supplies       Labels
# ...    ...         ...     ...              ...              ...          ...
# 11893  ...       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
# ...

# %%
##17
df["Sales"].sum()
# Out:
# np.float64(2297200.8603000003)

# %%
##18
df.groupby("State")["Sales"].sum()
# Out:
# State
# Alabama                  19510.6400
# Arizona                  35282.0010
# Arkansas                 11678.1300
# California              457687.6315
# Colorado                 32108.1180
# Connecticut              13384.3570
# Delaware                 27451.0690
# District of Columbia      2865.0200
# Florida                  89473.7080
# Georgia                  49095.8400
# Idaho                     4382.4860
# Illinois                 80166.1010
# Indiana                  53555.3600
# Iowa                      4579.7600
# Kansas                    2914.3100
# Kentucky                 36591.7500
# Louisiana                 9217.0300
# Maine                     1270.5300
# Maryland                 23705.5230
# Massachusetts            28634.4340
# Michigan                 76269.6140
# Minnesota                29863.1500
# Mississippi              10771.3400
# Missouri                 22205.1500
# Montana                   5589.3520
# Nebraska                  7464.9300
# ...

# %%
##19
sum_sales = data.groupby('Month')['Sales'].sum()
sum_sales
# Out:
# Month
# 1.0      95524.5664
# 2.0     105139.1240
# 3.0      72319.9246
# 4.0      68162.3390
# 5.0      64520.5088
# 6.0      53306.8580
# 7.0      62610.9065
# 8.0     101577.9506
# 9.0      66582.3650
# 10.0     62993.8410
# 11.0     69615.2315
# 12.0     65563.6962
# Name: Sales, dtype: float64

# %%
##20
df.groupby(["Country","City"])["Profit"].mean()
# Out:
# Country        City
# United States  Aberdeen      6.630000
#                               ...
#                Yuma       -116.497725
# Name: Profit, Length: 531, dtype: float64

# %%
##20
df.groupby("City")["Profit"].mean()
# Out:
# City
# Aberdeen      6.630000
#                ...
# Yuma       -116.497725
# Name: Profit, Length: 531, dtype: float64

# %%
##21
df.groupby("Region")["Profit"].mean()
# Out:
# Region
# Central    17.092709
# East       32.135808
# South      28.857673
# West       33.849032
# Name: Profit, dtype: float64

# %%
##22
ship_mode_profit = df.groupby('Ship Mode')['Profit'].mean()
ship_mode_profit
# Out:
# Ship Mode
# First Class       31.839948
# Same Day          29.266591
# Second Class      29.535545
# Standard Class    27.494770
# Name: Profit, dtype: float64

# %%
##23
loss_records = data[data['Profit'] < 0]
loss_records
# Out:
#       Serial_No       order _id Order Date   Ship Date       Ship Mode  \
# 3           4.0  US-2015-108966 2015-11-10  18-10-2015  Standard Class
# ...         ...             ...        ...         ...             ...
# 9962     9963.0  CA-2015-168088        NaT  22-03-2015     First Class
#
#      Customer ID     Customer Name      Segment        Country  \
# 3       SO-20335    Sean O'Donnell     Consumer  United States
# ...          ...               ...          ...            ...
# 9962    CM-12655  Corinna Mitchell  Home Office  United States
#
#                  City  ...       Product ID   Category Sub-Category  \
# 3     Fort Lauderdale  ...  FUR-TA-10000577  Furniture       Tables
# ...               ...  ...              ...        ...          ...
# 9962          Houston  ...  FUR-BO-10004218  Furniture    Bookcases
#
#                                            Product Name     Sales Quantity  \
# ...

# %%
##24
df.groupby("Category")["Sales"].sum()
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
df.groupby("Sub-Category")["Sales"].sum()
# Out:
# Sub-Category
# Accessories    167380.3180
# Appliances     107532.1610
# Art             27118.7920
# Binders        203412.7330
# Bookcases      114879.9963
# Chairs         328449.1030
# Copiers        149528.0300
# Envelopes       16476.4020
# Fasteners        3024.2800
# Furnishings     91705.1640
# Labels          12486.3120
# Machines       189238.6310
# Paper           78479.2060
# Phones         330007.0540
# Storage        223843.6080
# Supplies        46673.5380
# Tables         206965.5320
# Name: Sales, dtype: float64

# %%
df.groupby("Ship Date")["Profit"].mean()
# Out:
# Ship Date
# 01-01-2015    50.384164
#                 ...
# 31-12-2017    12.518950
# Name: Profit, Length: 1334, dtype: float64

# %%
#25
df[df['Discount']==0]
# Out:
#        Serial_No       order _id  Order Date   Ship Date     Ship Mode  \
# 1900         NaN             NaN  08-11-2016  11-11-2016  Second Class
# ...          ...             ...         ...         ...           ...
# 11893     9994.0  CA-2017-119914  04-05-2017  09-05-2017  Second Class
#
#       Customer ID Customer Name   Segment        Country         City  ...  \
# 1900     CG-12520   Claire Gute  Consumer  United States    Henderson  ...
# ...           ...           ...       ...            ...          ...  ...
# 11893    CC-12220  Chris Cortes  Consumer  United States  Westminster  ...
#
#       Postal Code  Region       Product ID         Category Sub-Category  \
# 1900        42420   South  FUR-BO-10001798        Furniture    Bookcases
# ...           ...     ...              ...              ...          ...
# 11893       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             Product Name   Sales  Quantity  \
# ...

# %%
##26
# data['Order Date'] = pd.to_datetime(data['Order Date'], errors='coerce')

cod1=df[((df['Ship Date']>='11-01-2016') & (df['Ship Date']<='11-30-2016'))]
cod2=df[((df['Order Date']>='11-01-2016') & (df['Order Date']<='11-01-2016'))]

# %%
cod2['Order Date']
# Out:
# 2925     11-01-2016
# 2926     11-01-2016
# 2927     11-01-2016
# 10421    11-01-2016
# Name: Order Date, dtype: object

# %%
cod2['Ship Date']
# Out:
# 2925     13-01-2016
# 2926     13-01-2016
# 2927     13-01-2016
# 10421    15-01-2016
# Name: Ship Date, dtype: object

# %%
cod1['Order Date']
# Out:
# 1900     08-11-2016
#             ...
# 11859    06-10-2017
# Name: Order Date, Length: 295, dtype: object

# %%
cod1['Ship Date']
# Out:
# 1900     11-11-2016
#             ...
# 11859    11-10-2017
# Name: Ship Date, Length: 295, dtype: object

# %%
##27

df[(df['Segment'] == 'Consumer') & (df['Profit'] > 0)]
# Out:
#        Serial_No       order _id  Order Date   Ship Date     Ship Mode  \
# 1900         NaN             NaN  08-11-2016  11-11-2016  Second Class
# ...          ...             ...         ...         ...           ...
# 11893     9994.0  CA-2017-119914  04-05-2017  09-05-2017  Second Class
#
#       Customer ID Customer Name   Segment        Country         City  ...  \
# 1900     CG-12520   Claire Gute  Consumer  United States    Henderson  ...
# ...           ...           ...       ...            ...          ...  ...
# 11893    CC-12220  Chris Cortes  Consumer  United States  Westminster  ...
#
#       Postal Code  Region       Product ID         Category Sub-Category  \
# 1900        42420   South  FUR-BO-10001798        Furniture    Bookcases
# ...           ...     ...              ...              ...          ...
# 11893       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             Product Name   Sales  Quantity  \
# ...

# %%
##28
state_dfs = {state: df_group for state, df_group in df.groupby('State')}
state_dfs
# Out:
# {'Alabama':        Serial_No       order _id  Order Date   Ship Date       Ship Mode  \
#  1979        80.0  CA-2016-127208  12-06-2016  15-06-2016     First Class
#  ...          ...             ...         ...         ...             ...
#  11569     9670.0  CA-2017-145275  02-04-2017  06-04-2017  Standard Class
#
#        Customer ID       Customer Name    Segment        Country     City  ...  \
#  1979     SC-20770  Stewart Carmichael  Corporate  United States  Decatur  ...
#  ...           ...                 ...        ...            ...      ...  ...
#  11569    AH-10465            Amy Hunt   Consumer  United States  Decatur  ...
#
#        Postal Code  Region       Product ID         Category Sub-Category  \
#  1979        35601   South  OFF-AP-10002118  Office Supplies   Appliances
#  ...           ...     ...              ...              ...          ...
#  11569       35601   South  OFF-LA-10001569  Office Supplies       Labels
#
# ...

# %%
##29
region=df.groupby(['Region','State'])[['Profit','Sales']].mean().reset_index()
region[region['Region']=='East']
# Out:
#    Region                 State      Profit       Sales
# 13   East           Connecticut   42.823071  163.223866
# 14   East              Delaware  103.930988  285.948635
# 15   East  District of Columbia  105.958930  286.502000
# 16   East                 Maine   56.810775  158.816250
# 17   East              Maryland   66.963608  225.766886
# 18   East         Massachusetts   50.262975  212.106919
# 19   East         New Hampshire   63.203807  270.093481
# 20   East            New Jersey   75.176260  275.110092
# 21   East              New York   65.637011  275.599531
# 22   East                  Ohio  -36.186304  166.861697
# 23   East          Pennsylvania  -26.507598  198.487077
# 24   East          Rhode Island  130.100523  404.070643
# 25   East               Vermont  204.088936  811.760909
# 26   East         West Virginia   46.480400  302.456000

# %%
##30
furniture_texas = df[(df['State'] == 'Texas') & (df['Category'] == 'Furniture')]
furniture_texas
# Out:
#        Serial_No       order _id  Order Date   Ship Date    Ship Mode  \
# 1936        37.0  CA-2016-117590  08-12-2016  10-12-2016  First Class
# ...          ...             ...         ...         ...          ...
# 11862     9963.0  CA-2015-168088  19-03-2015  22-03-2015  First Class
#
#       Customer ID     Customer Name      Segment        Country        City  \
# 1936     GH-14485         Gene Hale    Corporate  United States  Richardson
# ...           ...               ...          ...            ...         ...
# 11862    CM-12655  Corinna Mitchell  Home Office  United States     Houston
#
#        ... Postal Code   Region       Product ID   Category Sub-Category  \
# 1936   ...       75080  Central  FUR-FU-10003664  Furniture  Furnishings
# ...    ...         ...      ...              ...        ...          ...
# 11862  ...       77041  Central  FUR-BO-10004218  Furniture    Bookcases
#
#                                             Product Name     Sales  Quantity  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 6))
slices = [33,28,32,17]
region = ['West','South','East','Central']
cols = ['c','m','r','b']

plt.pie(slices,
        labels=region,
       colors=cols,
        startangle=90,
        textprops = {'fontsize':14, 'c':'g'},
        explode=(0,0.1,0,0.3),
        autopct='%1.2f%%')
plt.title('Region Wise Data')
# Out:
# Text(0.5, 1.0, 'Region Wise Data')

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
style.use('ggplot')
plt.scatter(df['Sales'], df['Profit'])
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.title('Sales vs Profit')
plt.legend()
plt.show()
# Out:
# C:\Users\91879\AppData\Local\Temp\ipykernel_3232\2702867223.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
data.columns
# Out:
# Index(['Serial_No', 'order _id', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Month',
#        'Year'],
#       dtype='object')

# %%
stack=df.groupby("Category")["Sales"].mean()

# %%
stack.index
# Out:
# Index(['Furniture', 'Office Supplies', 'Technology'], dtype='object', name='Category')

# %%
stack
# Out:
# Category
# Furniture          349.834887
# Office Supplies    119.324101
# Technology         452.709276
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(12, 6))
slices = [30,32,36]
category = ['Furniture','Office Supplies','Technology']
cols = ['c','m','y']

plt.pie(slices,
        labels=category,
       colors=cols,
        startangle=90,
        textprops = {'fontsize':14, 'c':'black'},
        explode=(0.1,0.1,0.1),
        autopct='%1.2f%%')
plt.title('Category')
# Out:
# Text(0.5, 1.0, 'Category')

# %%
import matplotlib.pyplot as plt

# %%
df
# Out:
#        Serial_No       order _id  Order Date   Ship Date     Ship Mode  \
# 1900         NaN             NaN  08-11-2016  11-11-2016  Second Class
# ...          ...             ...         ...         ...           ...
# 11893     9994.0  CA-2017-119914  04-05-2017  09-05-2017  Second Class
#
#       Customer ID Customer Name   Segment        Country         City  ...  \
# 1900     CG-12520   Claire Gute  Consumer  United States    Henderson  ...
# ...           ...           ...       ...            ...          ...  ...
# 11893    CC-12220  Chris Cortes  Consumer  United States  Westminster  ...
#
#       Postal Code  Region       Product ID         Category Sub-Category  \
# 1900        42420   South  FUR-BO-10001798        Furniture    Bookcases
# ...           ...     ...              ...              ...          ...
# 11893       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             Product Name   Sales  Quantity  \
# ...

# %%
plt.figure(figsize=(10, 7))
plt.bar(df['State'], df['Sales'], color='skyblue')
plt.title('Total Sales by State')
plt.xlabel('State')
plt.ylabel('Total Sales')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
sstack=df.groupby("Sub-Category")["Sales"].mean()

# %%
sstack.index
# Out:
# Index(['Accessories', 'Appliances', 'Art', 'Binders', 'Bookcases', 'Chairs',
#        'Copiers', 'Envelopes', 'Fasteners', 'Furnishings', 'Labels',
#        'Machines', 'Paper', 'Phones', 'Storage', 'Supplies', 'Tables'],
#       dtype='object', name='Sub-Category')

# %%
sstack
# Out:
# Sub-Category
# Accessories     215.974604
# Appliances      230.755710
# Art              34.068834
# Binders         133.560560
# Bookcases       503.859633
# Chairs          532.332420
# Copiers        2198.941618
# Envelopes        64.867724
# Fasteners        13.936774
# Furnishings      95.825668
# Labels           34.303055
# Machines       1645.553313
# Paper            57.284092
# Phones          371.211534
# Storage         264.590553
# Supplies        245.650200
# Tables          648.794771
# Name: Sales, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 8))
plt.bar(data['Sub-Category'], data['Sales'], color='pink')
plt.title('Sub-Category Sales')
plt.xlabel('Sub-Category')
plt.ylabel('Total Sales')
plt.xticks(rotation=90)
plt.legend()
plt.show()
# Out:
# C:\Users\91879\AppData\Local\Temp\ipykernel_3232\3010028731.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\91879\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
region_category_sales = data.groupby(['Region', 'Category'])['Sales'].sum().unstack()
region_category_sales.plot(kind='bar', stacked=True, figsize=(12, 6), colormap='viridis')
plt.title('Sales by Region and Category', fontsize=16)
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.xticks(rotation=90)
plt.show()

# %%
shippro = data.groupby(["Ship Mode"]).sum(["Profit"])

# %%
shippro
# Out:
#                  Serial_No  Postal Code         Sales  Quantity  Discount  \
# Ship Mode
# First Class      7498535.0     84229511  3.514284e+05      5693    253.17
# Same Day         2784998.0     31242093  1.283631e+05      1960     82.75
# Second Class     9601996.0    108192588  4.591936e+05      7423    270.15
# Standard Class  30059485.0    327908460  1.358216e+06     22797    955.02
#
#                      Profit    Month       Year
# Ship Mode
# First Class      48969.8399   3997.0  1276004.0
# Same Day         15891.7589   1674.0   497944.0
# Second Class     57446.6354   5027.0  1574305.0
# Standard Class  164088.7875  15383.0  4799301.0

# %%
shippro.index
# Out:
# Index(['First Class', 'Same Day', 'Second Class', 'Standard Class'], dtype='object', name='Ship Mode')

# %%
try:
    style.use('ggplot')
    plt.bar(shippro.index,shippro['Profit'],color=["g","r","b","m"])
    plt.xlabel("Ship Mode")
    plt.ylabel("Profit")
    plt.title("Ship mode vs Profit")
    plt.show()
except:
    print("Error Occured")

# %% [markdown]
# **-Plotly-**

# %%
import plotly.express as px

# %%
a=px.bar(data,x='Category',color="Category")
a.update_traces(marker_line_width=0)
a.show()

# %%
shippro = data.groupby(["Ship Mode"]).sum(["Profit"]).reset_index()

# %%
px.bar(shippro,x='Ship Mode',y='Profit',color='Ship Mode',text='Profit')

# %%
df.head()
# Out:
#       Serial_No       order _id  Order Date   Ship Date       Ship Mode  \
# 1900        NaN             NaN  08-11-2016  11-11-2016    Second Class
# 1901        2.0  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 1902        3.0  CA-2016-138688  12-06-2016  16-06-2016    Second Class
# 1903        4.0  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 1904        5.0  US-2015-108966  11-10-2015  18-10-2015  Standard Class
#
#      Customer ID    Customer Name    Segment        Country             City  \
# 1900    CG-12520      Claire Gute   Consumer  United States        Henderson
# 1901    CG-12520      Claire Gute   Consumer  United States        Henderson
# 1902    DV-13045  Darrin Van Huff  Corporate  United States      Los Angeles
# 1903    SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 1904    SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
# ...

# %%
dc=df[df['State']=="California"]

# %%
px.bar(dc,x='State',y='Profit')
